# %% [markdown]
# # Part 1. Import Libraries and explore dataset

# %% [markdown]
# By Cheng Liu, Juanxi Chen, Zhongwen Liang, Ziyi Ma, Xinmei Wang

# %%
#import nessassery packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read url from my github
#the url sometimes is not working properly
#please use below link to download the original dataset
#https://github.com/chengliu6/Sta160_code/blob/main/heart_disease_health_indicators_BRFSS2015.csv
url = 'https://raw.githubusercontent.com/chengliu6/Sta160_code/main/heart_disease_health_indicators_BRFSS2015.csv?token=GHSAT0AAAAAABTWGN5L7BOUYOVPBKR5KTRIYTWCPNQ'
df = pd.read_csv(url)

# %%
#find the structure of data
df.describe()
# Out:
#        HeartDiseaseorAttack         HighBP       HighChol      CholCheck  \
# count         253680.000000  253680.000000  253680.000000  253680.000000
# mean               0.094186       0.429001       0.424121       0.962670
# std                0.292087       0.494934       0.494210       0.189571
# min                0.000000       0.000000       0.000000       0.000000
# 25%                0.000000       0.000000       0.000000       1.000000
# 50%                0.000000       0.000000       0.000000       1.000000
# 75%                0.000000       1.000000       1.000000       1.000000
# max                1.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke       Diabetes  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean       28.382364       0.443169       0.040571       0.296921
# std         6.608694       0.496761       0.197294       0.698160
# ...

# %%
#check for null data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  float64
#  1   HighBP                253680 non-null  float64
#  2   HighChol              253680 non-null  float64
#  3   CholCheck             253680 non-null  float64
#  4   BMI                   253680 non-null  float64
#  5   Smoker                253680 non-null  float64
#  6   Stroke                253680 non-null  float64
#  7   Diabetes              253680 non-null  float64
#  8   PhysActivity          253680 non-null  float64
#  9   Fruits                253680 non-null  float64
#  10  Veggies               253680 non-null  float64
#  11  HvyAlcoholConsump     253680 non-null  float64
#  12  AnyHealthcare         253680 non-null  float64
#  13  NoDocbcCost           253680 non-null  float64
# ...

# %% [markdown]
# # Part 2. Data Visualization

# %%
#find the correlations between predictors
corr = df.corr()

# %% [markdown]
# Correlation heatmap

# %%
#heatmap style correlations
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_cd003_row0_col0, #T_cd003_row1_col1, #T_cd003_row2_col2, #T_cd003_row3_col3, #T_cd003_row4_col4, #T_cd003_row5_col5, #T_cd003_row6_col6, #T_cd003_row7_col7, #T_cd003_row8_col8, #T_cd003_row9_col9, #T_cd003_row10_col10, #T_cd003_row11_col11, #T_cd003_row12_col12, #T_cd003_row13_col13, #T_cd003_row14_col14, #T_cd003_row15_col15, #T_cd003_row16_col16, #T_cd003_row17_col17, #T_cd003_row18_col18, #T_cd003_row19_col19, #T_cd003_row20_col20, #T_cd003_row21_col21 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cd003_row0_col1, #T_cd003_row2_col7, #T_cd003_row10_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_cd003_row0_col2, #T_cd003_row4_col15, #T_cd003_row8_col10, #T_cd003_row11_col14, #T_cd003_row16_col6, #T_cd003_row17_col5, #T_cd003_row19_col5, #T_cd003_row21_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# ...

# %% [markdown]
# Heart Attack Counts in the dataset

# %%
#counts of the heart disease cases
sns.countplot(df["HeartDiseaseorAttack"]).set(title='Heart Disease Counts')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 1.0, 'Heart Disease Counts')]

# %%
#visulization of heart attack risk associated with sex and age
sns.barplot(df["Age"]*5,df["HeartDiseaseorAttack"],hue = df["Sex"]).set(title='Heart Disease Risk By Age and Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 1.0, 'Heart Disease Risk By Age and Sex')]

# %%
#visulization of heart attack risk associated with Education and income
sns.barplot(df['Income'],df["HeartDiseaseorAttack"],hue = df["Education"]).set(title='Heart Disease Risk By Education and Income')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 1.0, 'Heart Disease Risk By Education and Income')]

# %% [markdown]
# # Part 3. Machine Learning Methods To Predict Heart Attack

# %%
#import package
from sklearn.model_selection import train_test_split

#split predictor and outcome
predictors = df.drop("HeartDiseaseorAttack",axis=1)
outcome = df["HeartDiseaseorAttack"]

#split train and test sets
X_train,X_test,Y_train,Y_test = train_test_split(predictors,outcome,test_size=0.20,random_state=0)

# %%
#visualization function of difference between model and actural
def plot_comparison(predicted_data,actural_data,title):
  
  fig, axes = plt.subplots(1, 2, sharex=True, figsize=(10,5))
  fig.suptitle(title)

  sns.countplot(predicted_data,ax=axes[0])
  axes[0].set_title('Predicted')

  sns.countplot(actural_data,ax=axes[1])
  axes[1].set_title('Actual')

# %% [markdown]
# ### Logistic Regression

# %%
#import packages
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
#rescale the data to logistic regression
pipe = make_pipeline(StandardScaler(), LogisticRegression())

# %%
#fit the model find the accurancy score
pipe.fit(X_train, Y_train)
score_lr = pipe.score(X_test,Y_test)

# %%
#Compare two results
pred = pipe.predict(X_test)
arr = Y_test
plot_comparison(pred,arr,"Logistic regression result comparison")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
score_lr
# Out:
# 0.9095119836013876

# %% [markdown]
# ### SVM

# %%
#import package
from sklearn import svm

#fit model find the predicted outcome
sv = svm.LinearSVC()

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
#plot and compare two results
plot_comparison(Y_pred_svm,Y_test,"SVM result comparison")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
accuracy_score(Y_pred_svm,Y_test)
# Out:
# 0.9062795648060549

# %% [markdown]
# ### K Neighbors Classification

# %%
#import package
from sklearn.neighbors import KNeighborsClassifier

#fit the classifier and fit the data
knn = KNeighborsClassifier(n_neighbors=21)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)
#find accurancy score
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

# %%
#plot and compare two results
plot_comparison(Y_pred_knn,Y_test,"KNN result comparison")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
score_knn
# Out:
# 90.56
